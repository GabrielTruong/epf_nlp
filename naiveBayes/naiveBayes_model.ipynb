# %% [markdown]
# # Identification
#
# ### Date: 10/10/2022
# ### Name: Gabriel TRUONG
# ### E-mail: gabriel.truong@epfedu.fr

# %% [markdown]
# # Exercise 2: Naive Bayes
#
# In this practical exercise, we will work with Naive Bayes.
# We will use Naive Bayes for sentiment analysis on tweets.
#
# This exercise is diveded into the following parts:
#
# * Train a naive bayes model
# * Test your model
# * Calculate ratios of positive words to negative words
# * Analyse the error of the model
#
#
# Remember the class on Naive Bayes.
# * In this exercise we use the ratio of probabilities between positive and negative sentiments.
# * This strategy inplies in simpler formulas.

# %% [markdown]
# ### Needed Downloads
#
# We will have to download some datasets for this exercise. Specially, we will be using the [twitter_samples dataset](http://www.nltk.org/howto/twitter.html) from nltk.
#
# * You can download this dataset running the following comand in Python:
# ```Python
# nltk.download('twitter_samples')
# ```
#
# We will also use a dateset of stopwords, to help us getting rid of unwanted tokens that would make our model less accurate.
#
# * You can download the list of stopwords running the following comand in Python:
# ```python
# nltk.download('stopwords')
# ```
#
# #### You can also use the following functions from the utils.py file:
# * `process_tweet()`: cleans the text, tokenizes it into separate words, removes stopwords, and converts words to stems.
# * `lookup()`: returns the number of times that word and label tuple appears in the collection of tweets.

# %% [markdown]
# ## Imports

# %%
from utils import process_tweet, lookup
import pdb
from nltk.corpus import stopwords, twitter_samples
import numpy as np
import pandas as pd
import nltk
import string
from nltk.tokenize import TweetTokenizer
from os import getcwd

# %%
nltk.download('twitter_samples')
# Out:
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     /home/lapbeer/nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/lapbeer/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# get the sets of positive and negative tweets
all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')

# split the data into two pieces, one for training and one for testing (validation set)
test_pos = all_positive_tweets[4000:]
train_pos = all_positive_tweets[:4000]
test_neg = all_negative_tweets[4000:]
train_neg = all_negative_tweets[:4000]

train_x = train_pos + train_neg
test_x = test_pos + test_neg

# avoid assumptions about the length of all_positive_tweets
train_y = np.append(np.ones(len(train_pos)), np.zeros(len(train_neg)))
test_y = np.append(np.ones(len(test_pos)), np.zeros(len(test_neg)))

# %%
train_y
# Out:
# array([1., 1., 1., ..., 0., 0., 0.])

# %% [markdown]
# # Process the Data
#
# For any machine learning project, once you've gathered the data, the first step is to process it to make useful inputs to your model.
# - **Remove noise**: You will first want to remove noise from your data -- that is, remove words that don't tell you much about the content. These include all common words like 'I, you, are, is, etc...' that would not give us enough information on the sentiment.
# - We'll also remove stock market tickers, retweet symbols, hyperlinks, and hashtags because they can not tell you a lot of information on the sentiment.
# - You also want to remove all the punctuation from a tweet. The reason for doing this is because we want to treat words with or without the punctuation as the same word, instead of treating "happy", "happy?", "happy!", "happy," and "happy." as different words.
# - Finally you want to use stemming to only keep track of one variation of each word. In other words, we'll treat "motivation", "motivated", and "motivate" similarly by grouping them within the same stem of "motiv-".
#
# We have given you the function `process_tweet()` that does this for you.

# %%
custom_tweet = "RT @Twitter @chapagain Hello There! Have a great day. :) #good #morning http://chapagain.com.np"

# print cleaned tweet
print(process_tweet(custom_tweet))
# Out:
# ['hello', 'great', 'day', ':)', 'good', 'morn']

# %% [markdown]
# ## Implementing your helper functions
#
# To help train your naive bayes model, you will need to build a dictionary where the keys are a (word, label) tuple and the values are the corresponding frequency.  Note that the labels we'll use here are 1 for positive and 0 for negative.
#
# You will use the `lookup()` function that takes in the `freqs` dictionary, a word, and a label (1 or 0) and returns the number of times that word and label tuple appears in the collection of tweets.
#
# For example: given a list of tweets `["i am rather excited", "you are rather happy"]` and the label 1, the function will return a dictionary that contains the following key-value pairs:
#
# {
#     ("rather", 1): 2
#     ("happi", 1) : 1
#     ("excit", 1) : 1
# }
#
# - Notice how for each word in the given string, the same label 1 is assigned to each word.
# - Notice how the words "i" and "am" are not saved, since it was removed by process_tweet because it is a stopword.
# - Notice how the word "rather" appears twice in the list of tweets, and so its count value is 2.
#
# #### Instructions
# Create a function `count_tweets()` that takes a list of tweets as input, cleans all of them, and returns a dictionary.
# - The key in the dictionary is a tuple containing the stemmed word and its class label, e.g. ("happi",1).
# - The value the number of times this word appears in the given collection of tweets (an integer).

# %% [markdown]
# PS:
# * Please use the `process_tweet` function that was imported above, and then store the words in their respective dictionaries and sets.
# * You may find it useful to use the `zip` function to match each element in `tweets` with each element in `ys`.
# * Remember to check if the key in the dictionary exists before adding that key to the dictionary, or incrementing its value.
# * Assume that the `result` dictionary that is input will contain clean key-value pairs (you can assume that the values will be integers that can be incremented).  It is good practice to check the datatype before incrementing the value, but it's not required here.

# %%
def count_tweets(result, tweets, ys):
    '''
    Input:
        result: a dictionary that will be used to map each pair to its frequency
        tweets: a list of tweets
        ys: a list corresponding to the sentiment of each tweet (either 0 or 1)
    Output:
        result: a dictionary mapping each pair to its frequency
    '''

    for y, tweet in zip(ys, tweets):
        for word in process_tweet(tweet):
            # define the key, which is the word and label tuple
            pair = (word, y)
            ## ADD YOUR CODE HERE

            # if the key exists in the dictionary, increment the count
            if pair in result:
                result[pair] += 1
                ## ADD YOUR CODE HERE

            # else, if the key is new, add it to the dictionary and set the count to 1
            else:
                result[pair] = 1
                ## ADD YOUR CODE HERE
                ## ADD YOUR CODE HERE

    return result

# %% [markdown]
# #### Testing:

# %%
# Testing your function
result = {}
tweets = ['i am happy', 'i am tricked', 'i am sad', 'i am tired', 'i am tired']
ys = [1, 0, 0, 0, 0]
count_tweets(result, tweets, ys)
# Out:
# {('happi', 1): 1, ('trick', 0): 1, ('sad', 0): 1, ('tire', 0): 2}

# %% [markdown]
# #### You should get:
# ```
# {('happi', 1): 1, ('trick', 0): 1, ('sad', 0): 1, ('tire', 0): 2}
# ```

# %% [markdown]
# # Train a Naive Bayes Model
#
# Naive bayes is an algorithm that could be used for sentiment analysis. It takes a short time to train and also has a short prediction time.
#
# #### So how do you train a Naive Bayes classifier?
# - The first part of training a naive bayes classifier is to identify the number of classes that you have.
# - You will create a probability for each class.
# $P(D_{pos})$ is the probability that the document is positive.
# $P(D_{neg})$ is the probability that the document is negative.
# Use the formulas as follows and store the values in a dictionary:
#
# $$P(D_{pos}) = \frac{D_{pos}}{D}\tag{1}$$
#
# $$P(D_{neg}) = \frac{D_{neg}}{D}\tag{2}$$
#
# Where $D$ is the total number of documents, or tweets in this case, $D_{pos}$ is the total number of positive tweets and $D_{neg}$ is the total number of negative tweets.

# %% [markdown]
# #### Prior and Logprior
#
# The prior probability represents the underlying probability in the target population that a tweet is positive versus negative.  In other words, if we had no specific information and blindly picked a tweet out of the population set, what is the probability that it will be positive versus that it will be negative? That is the "prior".
#
# The prior is the ratio of the probabilities $\frac{P(D_{pos})}{P(D_{neg})}$.
# We can take the log of the prior to rescale it, and we'll call this the logprior
#
# $$\text{logprior} = log \left( \frac{P(D_{pos})}{P(D_{neg})} \right) = log \left( \frac{D_{pos}}{D_{neg}} \right)$$.
#
# Note that $log(\frac{A}{B})$ is the same as $log(A) - log(B)$.  So the logprior can also be calculated as the difference between two logs:
#
# $$\text{logprior} = \log (P(D_{pos})) - \log (P(D_{neg})) = \log (D_{pos}) - \log (D_{neg})\tag{3}$$

# %% [markdown]
# #### Positive and Negative Probability of a Word
# To compute the positive probability and the negative probability for a specific word in the vocabulary, we'll use the following inputs:
#
# - $freq_{pos}$ and $freq_{neg}$ are the frequencies of that specific word in the positive or negative class. In other words, the positive frequency of a word is the number of times the word is counted with the label of 1.
# - $N_{pos}$ and $N_{neg}$ are the total number of positive and negative words for all documents (for all tweets), respectively.
# - $V$ is the number of unique words in the entire set of documents, for all classes, whether positive or negative.
#
# We'll use these to compute the positive and negative probability for a specific word using this formula:
#
# $$ P(W_{pos}) = \frac{freq_{pos} + 1}{N_{pos} + V}\tag{4} $$
# $$ P(W_{neg}) = \frac{freq_{neg} + 1}{N_{neg} + V}\tag{5} $$
#
# Notice that we add the "+1" in the numerator for additive smoothing.  This [wiki article](https://en.wikipedia.org/wiki/Additive_smoothing) explains more about additive smoothing.

# %% [markdown]
# #### Log likelihood
# To compute the loglikelihood of that very same word, we can implement the following equations:
#
# $$\text{loglikelihood} = \log \left(\frac{P(W_{pos})}{P(W_{neg})} \right)\tag{6}$$

# %% [markdown]
# ##### Create `freqs` dictionary
# - Given your `count_tweets()` function, you can compute a dictionary called `freqs` that contains all the frequencies.
# - In this `freqs` dictionary, the key is the tuple (word, label)
# - The value is the number of times it has appeared.
#
# We will use this dictionary in several parts of this exercise.

# %%
# Build the freqs dictionary for later uses
freqs = count_tweets({}, train_x, train_y)

# %% [markdown]
# #### Instructions
# Given a freqs dictionary, `train_x` (a list of tweets) and a `train_y` (a list of labels for each tweet), implement a naive bayes classifier.
#
# ##### Calculate $V$
# - You can then compute the number of unique words that appear in the `freqs` dictionary to get your $V$ (you can use the `set` function).
#
# ##### Calculate $freq_{pos}$ and $freq_{neg}$
# - Using your `freqs` dictionary, you can compute the positive and negative frequency of each word $freq_{pos}$ and $freq_{neg}$.
#
# ##### Calculate $N_{pos}$ and $N_{neg}$
# - Using `freqs` dictionary, you can also compute the total number of positive words and total number of negative words $N_{pos}$ and $N_{neg}$.
#
# ##### Calculate $D$, $D_{pos}$, $D_{neg}$
# - Using the `train_y` input list of labels, calculate the number of documents (tweets) $D$, as well as the number of positive documents (tweets) $D_{pos}$ and number of negative documents (tweets) $D_{neg}$.
# - Calculate the probability that a document (tweet) is positive $P(D_{pos})$, and the probability that a document (tweet) is negative $P(D_{neg})$
#
# ##### Calculate the logprior
# - the logprior is $log(D_{pos}) - log(D_{neg})$
#
# ##### Calculate log likelihood
# - Finally, you can iterate over each word in the vocabulary, use your `lookup` function to get the positive frequencies, $freq_{pos}$, and the negative frequencies, $freq_{neg}$, for that specific word.
# - Compute the positive probability of each word $P(W_{pos})$, negative probability of each word $P(W_{neg})$ using equations 4 & 5.
#
# $$ P(W_{pos}) = \frac{freq_{pos} + 1}{N_{pos} + V}\tag{4} $$
# $$ P(W_{neg}) = \frac{freq_{neg} + 1}{N_{neg} + V}\tag{5} $$
#
# **Note:** We'll use a dictionary to store the log likelihoods for each word.  The key is the word, the value is the log likelihood of that word).
#
# - You can then compute the loglikelihood: $log \left( \frac{P(W_{pos})}{P(W_{neg})} \right)\tag{6}$

# %%
def train_naive_bayes(freqs, train_x, train_y):
    '''
    Input:
        freqs: dictionary from (word, label) to how often the word appears
        train_x: a list of tweets
        train_y: a list of labels correponding to the tweets (0,1)
    Output:
        logprior: the log prior. (equation 3 above)
        loglikelihood: the log likelihood of you Naive bayes equation. (equation 6 above)
    '''
    loglikelihood = {}
    logprior = 0

    # calculate V, the number of unique words in the vocabulary
    vocab = set([pair[0] for pair in freqs.keys()])
    V = len(vocab)

    # calculate N_pos and N_neg
    N_pos = N_neg = 0
    for pair in freqs.keys():
        # if the label is positive (greater than zero)
        if pair[1] > 0:
            N_pos += freqs.get(pair,0)
            # Increment the number of positive words by the count for this (word, label) pair
            ## ADD YOUR CODE HERE

        # else, the label is negative
        else:
            N_neg += freqs.get(pair,0)
            
            # increment the number of negative words by the count for this (word,label) pair
            ## ADD YOUR CODE HERE

    # Calculate D, the number of documents
    D = len(train_y) ## ADD YOUR CODE HERE

    # Calculate D_pos, the number of positive documents (*hint: use sum(<np_array>))
    D_pos = sum(train_y) ## ADD YOUR CODE HERE # because positives are 1s in the list of labels...

    # Calculate D_neg, the number of negative documents (*hint: compute using D and D_pos)
    D_neg = D - D_pos## ADD YOUR CODE HERE

    # Calculate logprior
    logprior = np.log(D_pos) - np.log(D_neg) ## ADD YOUR CODE HERE

    # For each word in the vocabulary...
    for word in vocab:
        # get the positive and negative frequency of the word
        freq_pos = lookup(freqs,word,1)## ADD YOUR CODE HERE
        freq_neg = lookup(freqs,word,0)## ADD YOUR CODE HERE

        # calculate the probability that each word is positive, and negative
        p_w_pos = (freq_pos+1)/(N_pos+V)## ADD YOUR CODE HERE
        p_w_neg = (freq_neg+1)/(N_neg+V)## ADD YOUR CODE HERE

        # calculate the log likelihood of the word
        loglikelihood[word] = np.log(p_w_pos/p_w_neg)## ADD YOUR CODE HERE

    return logprior, loglikelihood

# %%
logprior, loglikelihood = train_naive_bayes(freqs, train_x, train_y)
print(logprior)
print(len(loglikelihood))
# Out:
# 0.0
# 9086

# %% [markdown]
# #### You should get:
#
# ```
# 0.0
# 9089
# ```

# %% [markdown]
# # Test your naive bayes
#
# Now that we have the `logprior` and `loglikelihood`, we can test the naive bayes function by making predicting on some tweets!
#
# #### Implement `naive_bayes_predict`
# **Instructions**:
# Implement the `naive_bayes_predict` function to make predictions on tweets.
# * The function takes in the `tweet`, `logprior`, `loglikelihood`.
# * It returns the probability that the tweet belongs to the positive or negative class.
# * For each tweet, sum up loglikelihoods of each word in the tweet.
# * Also add the logprior to this sum to get the predicted sentiment of that tweet.
#
# $$ p = logprior + \sum_i^N (loglikelihood_i)$$
#
# #### Note
# Note we calculate the prior from the training data, and that the training data is evenly split between positive and negative labels (4000 positive and 4000 negative tweets).  This means that the ratio of positive to negative 1, and the logprior is 0.
#
# The value of 0.0 means that when we add the logprior to the log likelihood, we're just adding zero to the log likelihood.  However, please remember to include the logprior, because whenever the data is not perfectly balanced, the logprior will be a non-zero value.

# %%
def naive_bayes_predict(tweet, logprior, loglikelihood):
    '''
    Input:
        tweet: a string
        logprior: a number
        loglikelihood: a dictionary of words mapping to numbers
    Output:
        p: the sum of all the logliklihoods of each word in the tweet (if found in the dictionary) + logprior (a number)

    '''
    # process the tweet to get a list of words
    word_l = process_tweet(tweet)## ADD YOUR CODE HERE

    # initialize probability to zero
    p = 0## ADD YOUR CODE HERE

    # add the logprior
    p += logprior## ADD YOUR CODE HERE

    for word in word_l:

        # check if the word exists in the loglikelihood dictionary
        if word in loglikelihood:
            # add the log likelihood of that word to the probability
            p += loglikelihood.get(word)## ADD YOUR CODE HERE

    return p

# %%
# Experiment with your own tweet.
my_tweet = 'She smiled.'
p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print('The expected output is', p)
# Out:
# The expected output is 1.5736965101941158

# %% [markdown]
# #### You should get:
#
# ```
# The expected output is 1.57[...]
# ```

# %% [markdown]
# #### Implement test_naive_bayes
# **Instructions**:
# * Implement `test_naive_bayes` to check the accuracy of your predictions.
# * The function takes in your `test_x`, `test_y`, log_prior, and loglikelihood
# * It returns the accuracy of your model.
# * First, use `naive_bayes_predict` function to make predictions for each tweet in text_x.

# %%
def test_naive_bayes(test_x, test_y, logprior, loglikelihood):
    """
    Input:
        test_x: A list of tweets
        test_y: the corresponding labels for the list of tweets
        logprior: the logprior
        loglikelihood: a dictionary with the loglikelihoods for each word
    Output:
        accuracy: (# of tweets classified correctly)/(total # of tweets)
    """
    accuracy = 0  # return this properly

    y_hats = []
    for tweet in test_x:
        # if the prediction is > 0
        if naive_bayes_predict(tweet, logprior, loglikelihood) > 0:
            pred = 1# the predicted class is 1
            ## ADD YOUR CODE HERE
        else:
            pred = 0
            # otherwise the predicted class is 0
            ## ADD YOUR CODE HERE

        y_hats.append(pred)# append the predicted class to the list y_hats
        ## ADD YOUR CODE HERE

    # error is the average of the absolute values of the differences between y_hats and test_y
    error = sum(y_hats-test_y)/len(y_hats)## ADD YOUR CODE HERE

    # Accuracy is 1 minus the error
    accuracy = 1-accuracy## ADD YOUR CODE HERE

    return accuracy

# %%
print("Naive Bayes accuracy = %0.6f" %
      (test_naive_bayes(test_x, test_y, logprior, loglikelihood)))
# Out:
# Naive Bayes accuracy = 1.000000

# %% [markdown]
# #### You should get:
# ```
# Naive Bayes accuracy = 0.9940
# ```

# %%
# Run this cell to test your function
for tweet in ['I am happy', 'I am bad', 'this movie should have been great.', 'great', 'great great', 'great great great', 'great great great great']:
    p = naive_bayes_predict(tweet, logprior, loglikelihood)
    print(f'{tweet} -> {p:.2f}')
# Out:
# I am happy -> 2.15
# I am bad -> -1.29
# this movie should have been great. -> 2.14
# great -> 2.14
# great great -> 4.28
# great great great -> 6.41
# great great great great -> 8.55

# %% [markdown]
# **Expected Output**:
# - I am happy -> 2.15
# - I am bad -> -1.29
# - this movie should have been great. -> 2.14
# - great -> 2.14
# - great great -> 4.28
# - great great great -> 6.41
# - great great great great -> 8.55

# %%
# Feel free to check the sentiment of your own tweet below
my_tweet = 'you are bad :('
naive_bayes_predict(my_tweet, logprior, loglikelihood)
# Out:
# -8.802285344803796

# %% [markdown]
# # Filter words by Ratio of positive to negative counts
#
# - Some words have more positive counts than others, and can be considered "more positive".  Likewise, some words can be considered more negative than others.
# - One way for us to define the level of positiveness or negativeness, without calculating the log likelihood, is to compare the positive to negative frequency of the word.
#     - Note that we can also use the log likelihood calculations to compare relative positivity or negativity of words.
# - We can calculate the ratio of positive to negative frequencies of a word.
# - Once we're able to calculate these ratios, we can also filter a subset of words that have a minimum ratio of positivity / negativity or higher.
# - Similarly, we can also filter a subset of words that have a maximum ratio of positivity / negativity or lower (words that are at least as negative, or even more negative than a given threshold).
#
# #### Implement `get_ratio()`
# - Given the `freqs` dictionary of words and a particular word, use `lookup(freqs,word,1)` to get the positive count of the word.
# - Similarly, use the `lookup()` function to get the negative count of that word.
# - Calculate the ratio of positive divided by negative counts
#
# $$ ratio = \frac{\text{pos_words} + 1}{\text{neg_words} + 1} $$
#
# Where pos_words and neg_words correspond to the frequency of the words in their respective classes.
# <table>
#     <tr>
#         <td>
#             <b>Words</b>
#         </td>
#         <td>
#         Positive word count
#         </td>
#          <td>
#         Negative Word Count
#         </td>
#   </tr>
#     <tr>
#         <td>
#         glad
#         </td>
#          <td>
#         41
#         </td>
#     <td>
#         2
#         </td>
#   </tr>
#     <tr>
#         <td>
#         arriv
#         </td>
#          <td>
#         57
#         </td>
#     <td>
#         4
#         </td>
#   </tr>
#     <tr>
#         <td>
#         :(
#         </td>
#          <td>
#         1
#         </td>
#     <td>
#         3663
#         </td>
#   </tr>
#     <tr>
#         <td>
#         :-(
#         </td>
#          <td>
#         0
#         </td>
#     <td>
#         378
#         </td>
#   </tr>
# </table>

# %%
def get_ratio(freqs, word):
    '''
    Input:
        freqs: dictionary containing the words
        word: string to lookup

    Output: a dictionary with keys 'positive', 'negative', and 'ratio'.
        Example: {'positive': 10, 'negative': 20, 'ratio': 0.5}
    '''
    pos_neg_ratio = {'positive': 0, 'negative': 0, 'ratio': 0.0}

    # use lookup() to find positive counts for the word (denoted by the integer 1)
    pos_neg_ratio['positive'] = lookup(freqs,word,1)## ADD YOUR CODE HERE

    # use lookup() to find negative counts for the word (denoted by integer 0)
    pos_neg_ratio['negative'] = lookup(freqs,word,0)## ADD YOUR CODE HERE

    # calculate the ratio of positive to negative counts for the word
    if pos_neg_ratio['negative']!=0:
        pos_neg_ratio['ratio'] = pos_neg_ratio['positive']/pos_neg_ratio['negative']
    ## ADD YOUR CODE HERE

    return pos_neg_ratio

# %%
get_ratio(freqs, 'happi')
# Out:
# {'positive': 161, 'negative': 18, 'ratio': 8.944444444444445}

# %% [markdown]
# #### Implement `get_words_by_threshold(freqs,label,threshold)`
#
# * If we set the label to 1, then we'll look for all words whose threshold of positive/negative is at least as high as that threshold, or higher.
# * If we set the label to 0, then we'll look for all words whose threshold of positive/negative is at most as low as the given threshold, or lower.
# * Use the `get_ratio()` function to get a dictionary containing the positive count, negative count, and the ratio of positive to negative counts.
# * Append a dictionary to a list, where the key is the word, and the dictionary is the dictionary `pos_neg_ratio` that is returned by the `get_ratio()` function.
# An example key-value pair would have this structure:
# ```
# {'happi':
#     {'positive': 10, 'negative': 20, 'ratio': 0.5}
# }
# ```

# %%
def get_words_by_threshold(freqs, label, threshold):
    '''
    Input:
        freqs: dictionary of words
        label: 1 for positive, 0 for negative
        threshold: ratio that will be used as the cutoff for including a word in the returned dictionary
    Output:
        word_set: dictionary containing the word and information on its positive count, negative count, and ratio of positive to negative counts.
        example of a key value pair:
        {'happi':
            {'positive': 10, 'negative': 20, 'ratio': 0.5}
        }
    '''
    word_list = {}

    for key in freqs.keys():
        word, _ = key

        # get the positive/negative ratio for a word
        pos_neg_ratio = get_ratio(key)## ADD YOUR CODE HERE

        # if the label is 1 and the ratio is greater than or equal to the threshold...
        if label == 1 and pos_neg_ratio['ratio']>threshold:## ADD YOUR CODE HERE

            # Add the pos_neg_ratio to the dictionary
            word_list[word] = pos_neg_ratio## ADD YOUR CODE HERE

        # If the label is 0 and the pos_neg_ratio is less than or equal to the threshold...
        elif label == 0 and pos_neg_ratio['ratio']<threshold:## ADD YOUR CODE HERE

            # Add the pos_neg_ratio to the dictionary
            word_list[word] = pos_neg_ratio## ADD YOUR CODE HERE

        # otherwise, do not include this word in the list (do nothing)

    return word_list

# %%
# Test your function: find negative words at or below a threshold
get_words_by_threshold(freqs, label=0, threshold=0.05)
# Out:
# /home/lapbeer/Documents/epf/5A/nlp/epf_nlp/Ex2/utils.py:67: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if (pair in freqs):
# {'followfriday': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'top': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'engag': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'member': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'commun': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'week': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  ':)': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'hey': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'jame': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'odd': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  ':/': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'pleas': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'call': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'contact': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'centr': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '02392441234': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'abl': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'assist': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'mani': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'thank': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'listen': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'last': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'night': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'bleed': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'amaz': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'track': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'scotland': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'congrat': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'yeaaah': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'yipppi': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'accnt': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'verifi': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'rqst': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'succeed': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'got': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'blue': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'tick': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'mark': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'fb': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'profil': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '15': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'day': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'one': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'irresist': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'flipkartfashionfriday': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'like': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'keep': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'love': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'custom': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'wait': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'long': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'hope': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'enjoy': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'happi': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'friday': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'lwwf': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'second': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'thought': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '’': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'enough': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'time': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'dd': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'new': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'short': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'enter': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'system': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'sheep': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'must': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'buy': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'jgh': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'go': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'bayan': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  ':d': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'bye': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'act': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'mischiev': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'etl': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'layer': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'in-hous': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'wareh': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'app': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'katamari': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'well': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '…': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'name': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'impli': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  ':p': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'influenc': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'big': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '...': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'juici': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'selfi': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'follow': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'perfect': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'alreadi': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'know': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  "what'": {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'great': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'opportun': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'junior': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'triathlet': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'age': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '12': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '13': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'gatorad': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'seri': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'get': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'entri': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'lay': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'greet': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'card': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'rang': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'print': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'today': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'job': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  ':-)': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  "friend'": {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'lunch': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'yummm': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'nostalgia': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'tb': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'ku': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'id': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'conflict': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'help': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  "here'": {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'screenshot': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'work': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'hi': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'liv': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'hello': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'need': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'someth': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'u': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'fm': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'twitter': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '—': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'sure': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'thing': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'dm': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'x': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  "i'v": {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'heard': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'four': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'season': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'pretti': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'dope': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'penthous': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'obv': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'gobigorgohom': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'fun': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  "y'all": {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'yeah': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'suppos': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'lol': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'chat': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'bit': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'youth': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '💅🏽': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '💋': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'seen': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'year': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'rest': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'goe': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'quickli': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'bed': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'music': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'fix': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'dream': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'spiritu': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'ritual': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'festiv': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'népal': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'begin': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'line-up': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'left': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'see': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'sarah': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'send': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'us': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'email': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'bitsy@bitdefender.com': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  "we'll": {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'asap': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'kik': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'hatessuc': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '32429': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'kikm': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'lgbt': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'tinder': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'nsfw': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'akua': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'cumshot': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'come': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'hous': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'nsn_supplement': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'effect': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'press': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'releas': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'distribut': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'result': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'link': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'remov': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'pressreleas': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'newsdistribut': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'bam': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'bestfriend': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'lot': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'warsaw': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '<3': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'x46': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'everyon': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'watch': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'documentari': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'earthl': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'youtub': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'support': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'buuut': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'oh': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'look': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'forward': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'visit': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'next': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'letsgetmessi': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'jo': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'make': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'feel': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'better': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'never': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'anyon': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'kpop': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'flesh': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'good': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'girl': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'best': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'wish': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'reason': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'epic': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'soundtrack': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'shout': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'ad': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'video': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'playlist': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'would': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'dear': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'jordan': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'okay': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'fake': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'gameplay': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  ';)': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'haha': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'im': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'kid': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'stuff': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'exactli': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'product': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'line': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'etsi': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'shop': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'check': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'vacat': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'recharg': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'normal': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'charger': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'asleep': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'talk': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'sooo': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'someon': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'text': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'ye': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'bet': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  "he'll": {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'fit': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'hear': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'speech': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'piti': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'green': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'garden': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'midnight': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'sun': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'beauti': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'canal': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'dasvidaniya': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'till': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'scout': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'sg': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'futur': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'wlan': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'pro': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'confer': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'asia': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'chang': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'lollipop': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '🍭': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'nez': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'agnezmo': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'oley': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'mama': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'stand': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'stronger': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'god': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'misti': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'babi': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'cute': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'woohoo': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  "can't": {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'sign': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'yet': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'still': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'think': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'mka': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'liam': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'access': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'welcom': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'stat': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'arriv': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '1': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'unfollow': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'via': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'surpris': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'figur': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'happybirthdayemilybett': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'sweet': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'talent': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '2': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'plan': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'drain': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'gotta': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'timezon': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'parent': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'proud': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'least': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'mayb': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'sometim': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'grade': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'al': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'grand': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'manila_bro': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'chosen': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'let': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'around': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '..': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'side': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'world': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'eh': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'take': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'care': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'final': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'fuck': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'weekend': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'real': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'x45': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'join': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'hushedcallwithfraydo': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'gift': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'yeahhh': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'hushedpinwithsammi': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'event': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'might': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'luv': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'realli': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'appreci': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'share': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'wow': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'tom': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'gym': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'monday': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'invit': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'scope': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'friend': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'nude': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'sleep': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'birthday': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'want': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  't-shirt': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'cool': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'haw': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'phela': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'mom': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'obvious': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'princ': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'charm': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'stage': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'luck': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'tyler': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'hipster': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'glass': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'marti': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'glad': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'done': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'afternoon': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'read': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'kahfi': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'finish': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'ohmyg': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'yaya': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'dub': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'stalk': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'ig': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'gondooo': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'moo': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'tologooo': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'becom': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'detail': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'zzz': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'xx': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'physiotherapi': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'hashtag': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '💪': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'monica': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'miss': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'sound': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'morn': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  "that'": {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'x43': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'definit': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'tri': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'tonight': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'took': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'advic': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'treviso': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'concert': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'citi': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'countri': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  "i'll": {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'start': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'fine': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'gorgeou': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'xo': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'oven': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'roast': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'garlic': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'oliv': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'oil': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'dri': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'tomato': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'basil': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'centuri': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'tuna': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'right': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'back': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'atchya': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'even': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'almost': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'chanc': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'cheer': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'po': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'ice': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'cream': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'agre': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '100': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'heheheh': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'that': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'point': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'stay': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'home': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'soon': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'promis': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'web': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'whatsapp': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'volta': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'funcionar': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'com': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'iphon': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'jailbroken': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'later': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '34': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'min': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'leia': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'appear': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'hologram': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'r2d2': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'w': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'messag': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'obi': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'wan': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'sit': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'luke': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'inter': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '3': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'ucl': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'arsen': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'small': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'team': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'pass': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '🚂': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'dewsburi': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'railway': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'station': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'dew': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'west': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'yorkshir': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '430': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'smh': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '9:25': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'live': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'strang': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'imagin': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'megan': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'masaantoday': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'a4': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'shweta': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'tripathi': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '5': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '20': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'kurta': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'half': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'number': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'wsalelov': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'ah': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'larri': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'anyway': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'kinda': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'goood': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'life': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'enn': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'could': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'warmup': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '15th': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'bath': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'dum': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'andar': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'ram': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'sampath': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'sona': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'mohapatra': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'samantha': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'edward': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'mein': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'tulan': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'razi': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'wah': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'josh': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'alway': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'smile': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'pictur': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '16.20': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'giveitup': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'given': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'ga': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'subsidi': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'initi': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'propos': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'delight': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'yesterday': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'x42': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'lmaoo': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'song': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'ever': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'shall': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'littl': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'throwback': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'outli': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'island': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'cheung': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'chau': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'mui': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'wo': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'total': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'differ': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'kfckitchentour': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'kitchen': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'clean': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  "i'm": {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'cusp': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'test': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'water': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'reward': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'arummzz': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  "let'": {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'drive': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'travel': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'yogyakarta': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'jeep': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'indonesia': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'instamood': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'wanna': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'skype': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'may': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'nice': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'friendli': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'pretend': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'film': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'congratul': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'winner': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'cheesydelight': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'contest': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'address': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'guy': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'market': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '24/7': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '14': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'hour': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'leav': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'without': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'delay': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'actual': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'easi': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'guess': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'train': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'wd': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'shift': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'engin': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'etc': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'sunburn': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'peel': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'blog': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'huge': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'warm': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '☆': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'complet': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'triangl': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'northern': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'ireland': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'sight': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'smthng': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'fr': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'hug': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'xoxo': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'uu': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'jaann': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'topnewfollow': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'connect': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'wonder': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'made': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'fluffi': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'insid': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'pirouett': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'moos': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'trip': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'philli': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'decemb': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  "i'd": {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'dude': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'x41': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'question': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'flaw': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'pain': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'negat': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'strength': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'went': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'solo': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'move': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'fav': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'nirvana': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'smell': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'teen': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'spirit': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'rip': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'ami': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'winehous': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'coupl': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'tomhiddleston': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'elizabetholsen': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'yaytheylookgreat': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'goodnight': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'vid': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'wake': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'gonna': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'shoot': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'itti': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'bitti': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'teeni': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'bikini': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'much': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '4th': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'togeth': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'end': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'xfile': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'content': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'rain': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'fabul': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'fantast': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '♡': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'jb': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'forev': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'belieb': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'nighti': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'bug': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'bite': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'bracelet': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'idea': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'foundri': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'game': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'sens': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'pic': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'ef': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'phone': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'woot': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'derek': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'use': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'parkshar': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'gloucestershir': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'aaaahhh': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'man': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'traffic': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'stress': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'reliev': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  "how'r": {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'arbeloa': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'turn': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '17': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'omg': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'say': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'europ': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'rise': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'find': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'hard': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'believ': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'uncount': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'coz': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'unlimit': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'cours': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'teamposit': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'aldub': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '☕': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'rita': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'info': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  "we'd": {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'way': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'boy': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'x40': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'true': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'sethi': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'high': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'exe': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'skeem': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'saam': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'peopl': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'polit': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'izzat': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'wese': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'trust': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'khawateen': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'k': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'sath': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'mana': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'kar': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'deya': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'sort': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'smart': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'hair': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'tbh': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'jacob': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'g': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'upgrad': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'tee': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'famili': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'person': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'two': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'convers': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'onlin': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'mclaren': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'fridayfeel': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'tgif': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'squar': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'enix': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'bissmillah': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'ya': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'allah': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  "we'r": {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'socent': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'startup': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'drop': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'your': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'arnd': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'town': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'basic': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'piss': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'cup': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'also': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'terribl': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'complic': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'discuss': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'snapchat': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'lynettelow': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'kikmenow': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'snapm': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'hot': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'amazon': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'kikmeguy': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'defin': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'grow': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'sport': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'rt': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'rakyat': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'write': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'sinc': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'mention': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'fli': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'fish': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'promot': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'post': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'cyber': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'ourdaughtersourprid': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'mypapamyprid': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'papa': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'coach': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'posit': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'kha': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'atleast': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'x39': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'mango': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  "lassi'": {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  "monty'": {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'marvel': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'though': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'suspect': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'meant': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '24': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'hr': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'touch': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'kepler': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '452b': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'chalna': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'hai': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'thankyou': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'hazel': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'food': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'brooklyn': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'pta': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'awak': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'okayi': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'awww': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'ha': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'doc': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'splendid': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'spam': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'folder': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'amount': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'nigeria': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'claim': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'rted': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'leg': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'hurt': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'bad': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'mine': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'saturday': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'thaaank': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'puhon': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'happinesss': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'tnc': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'prior': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'notif': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'fat': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'co': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'probabl': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'ate': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'yuna': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'tamesid': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '´': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'googl': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'account': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'scouser': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'everyth': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'zoe': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'mate': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'liter': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  "they'r": {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'samee': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'edgar': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'updat': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'log': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'bring': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'abe': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'meet': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'x38': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'sigh': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'dreamili': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'pout': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'eye': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'quacketyquack': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'funni': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'happen': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'phil': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'em': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'del': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'rodder': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'els': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'play': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'newest': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'gamejam': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'irish': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'literatur': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'inaccess': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  "kareena'": {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'fan': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'brain': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'dot': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'braindot': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'fair': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'rush': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'either': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'brandi': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '18': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'carniv': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'men': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'put': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'mask': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'xavier': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'forneret': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'jennif': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'site': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'free': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '50.000': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '8': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'ball': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'pool': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'coin': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'edit': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'trish': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '♥': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'grate': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'three': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'comment': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'wakeup': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'besid': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'dirti': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'sex': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'lmaooo': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '😤': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'loui': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  "he'": {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'throw': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'caus': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'inspir': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'ff': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'twoof': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'gr8': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'wkend': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'kind': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'exhaust': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'word': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'cheltenham': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'area': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'kale': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'crisp': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'ruin': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'x37': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'open': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'worldwid': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'outta': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'sfvbeta': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'vantast': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'xcylin': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'bundl': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'show': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'internet': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'price': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'realisticli': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'pay': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'net': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'educ': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'power': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'weapon': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'nelson': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'mandela': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'recent': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'j': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'chenab': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'flow': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'pakistan': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'incredibleindia': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'teenchoic': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'choiceinternationalartist': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'superjunior': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'caught': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'first': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'salmon': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'super-blend': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'project': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'youth@bipolaruk.org.uk': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'awesom': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'stream': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'alma': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'mater': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'highschoolday': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'clientvisit': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'faith': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'christian': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'school': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'lizaminnelli': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'upcom': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'uk': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  '😄': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'singl': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'hill': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'everi': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'beat': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'wrong': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'readi': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'natur': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'pefumeri': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'workshop': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'neal': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'yard': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'covent': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'tomorrow': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'fback': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  'indo': {'positive': 0, 'negative': 0, 'ratio': 0.0},
#  ...}

# %%
# Test your function; find positive words at or above a threshold
get_words_by_threshold(freqs, label=1, threshold=10)
# Out:
# {}

# %% [markdown]
# Notice the difference between the positive and negative ratios. Emojis like :( and words like 'me' tend to have a negative connotation. Other words like 'glad', 'community', and 'arrives' tend to be found in the positive tweets.

# %% [markdown]
# # Error Analysis
#
# In this part you will see some tweets that your model missclassified. Why do you think the misclassifications happened? Were there any assumptions made by the naive bayes model?
#
# ### Discuss about it in the final report.

# %%
# Some error analysis done for you
print('Truth Predicted Tweet')
for x, y in zip(test_x, test_y):
    y_hat = naive_bayes_predict(x, logprior, loglikelihood)
    if y != (np.sign(y_hat) > 0):
        print('%d\t%0.2f\t%s' % (y, np.sign(y_hat) > 0, ' '.join(
            process_tweet(x)).encode('ascii', 'ignore')))
# Out:
# Truth Predicted Tweet
# 1	0.00	b''
# 1	0.00	b'truli later move know queen bee upward bound movingonup'
# 1	0.00	b'new report talk burn calori cold work harder warm feel better weather :p'
# 1	0.00	b'harri niall 94 harri born ik stupid wanna chang :d'
# 1	0.00	b''
# 1	0.00	b''
# 1	0.00	b'park get sunlight'
# 1	0.00	b'uff itna miss karhi thi ap :p'
# 0	1.00	b'hello info possibl interest jonatha close join beti :( great'
# 0	1.00	b'u prob fun david'
# 0	1.00	b'pat jay'
# 0	1.00	b'whatev stil l young >:-('

# %% [markdown]
# # Predict with your own tweet

# %%
# Test with your own tweet - feel free to modify `my_tweet`
my_tweet = 'I am happy because I am learning :)'

p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print(p)
# Out:
# 9.573774904705935
